# %%
constants = {
    'VALID_NOISE_STRENGHTS': ['low', 'medium', 'high'],
    'VALID_NOISE_TYPES': ['gaussian','s&p', 'speckle', 'all'],
    'noise_dictionary': {
        'low': {
            'gaussian': {
                'min': 0.001,
                'max': 0.0025
            },
            's&p': {
                'min': 0.01,
                'max': 0.05
            },
            'speckle': {
                'min': 0.01,
                'max': 0.04
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
        'medium': {
            'gaussian': {
                'min': 0.0025,
                'max': 0.0139
            },
            's&p': {
                'min': 0.05,
                'max': 0.09
            },
            'speckle': {
                'min': 0.04,
                'max': 0.09
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
        'high': {
            'gaussian': {
                'min': 0.0139,
                'max': 0.07
            },
            's&p': {
                'min': 0.09,
                'max': 0.30
            },
            'speckle': {
                'min': 0.09,
                'max': 0.7
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        }
    },
    'categorical_classes_dictionary': {
        'gaussian': 0,
        's&p': 1,
        'speckle': 2,
        'clean': 3
    },
    'base_name_dae_images' : 'dae_images_',
    'base_name_pca_images' : 'pca_images_',
    'path_images' : 'data\\custom_noises',
    'noise_levels_dictionary' : {
        'level1': {
            'gaussian': {
                'min': 0.01 ** 2,
                'max': 0.1 ** 2
            },
            's&p': {
                'min': 0.01 ** 2,
                'max': 0.05
            },
            'speckle': {
                'min': 0.01 ** 2,
                'max': 0.2 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            },
        },
        'level2': {
            'gaussian': {
                'min': 0.1 ** 2,
                'max': 0.2 ** 2
            },
            's&p': {
                'min': 0.05,
                'max': 0.10
            },
            'speckle': {
                'min': 0.2 ** 2,
                'max': 0.3 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
        'level3': {
            'gaussian': {
                'min': 0.2 ** 2,
                'max': 0.3 ** 2
            },
            's&p': {
                'min': 0.10,
                'max': 0.15
            },
            'speckle': {
                'min': 0.3 ** 2,
                'max': 0.4 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
        'level4': {
            'gaussian': {
                'min': 0.3 ** 2,
                'max': 0.4 ** 2
            },
            's&p': {
                'min': 0.15,
                'max': 0.2
            },
            'speckle': {
                'min': 0.4 ** 2,
                'max': 0.5 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
         'level5': {
            'gaussian': {
                'min': 0.4 ** 2,
                'max': 0.5 ** 2
            },
            's&p': {
                'min': 0.2,
                'max': 0.25
            },
            'speckle': {
                'min': 0.5 ** 2,
                'max': 0.6 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
         'level6': {
            'gaussian': {
                'min': 0.5 ** 2,
                'max': 0.6 ** 2
            },
            's&p': {
                'min': 0.25,
                'max': 0.3
            },
            'speckle': {
                'min': 0.6 ** 2,
                'max': 0.7 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
         'level7': {
            'gaussian': {
                'min': 0.6 ** 2,
                'max': 0.7 ** 2
            },
            's&p': {
                'min': 0.3,
                'max': 0.35
            },
            'speckle': {
                'min': 0.7 ** 2,
                'max': 0.8 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
         'level8': {
            'gaussian': {
                'min': 0.7 ** 2,
                'max': 0.8 ** 2
            },
            's&p': {
                'min': 0.35,
                'max': 0.4
            },
            'speckle': {
                'min': 0.8 ** 2,
                'max': 0.9 ** 2
            },
            'clean': {
                'min': 0.0,
                'max': 0.0 
            }
        },
    }
}

# %%
# Serializing json  
import json
with open("constants.json", "w") as write_file:
    json.dump(constants, write_file, indent=4, sort_keys=False) # encode dict into JSON
